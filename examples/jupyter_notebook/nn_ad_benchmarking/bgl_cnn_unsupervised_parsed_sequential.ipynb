# %% [markdown]
# ### Log Anomaly Detection on BGL Dataset using Transformer based models
# This is a running example of an end-to-end workflow for Log Anomaly Detection on public dataset BGL using Transformer based neural anomaly detectors.
#
# It is very similar to that on the HDFS dataset. We will only mark out the dataset specific portions of this workflow i.e. the parts that differ between the two datasets.
#
# For a more complete elaboration of the full workflow please refer to `hdfs_lstm_unsupervised_parsed_sequential.ipynb` notebook.

# %%
import os 
from logai.applications.openset.anomaly_detection.openset_anomaly_detection_workflow import OpenSetADWorkflowConfig, validate_config_dict
from logai.utils.file_utils import read_file
from logai.utils.dataset_utils import split_train_dev_test_for_anomaly_detection
import logging 
from logai.dataloader.data_loader import FileDataLoader
from logai.preprocess.bgl_preprocessor import BGLPreprocessor
from logai.information_extraction.log_parser import LogParser
from logai.preprocess.openset_partitioner import OpenSetPartitioner
from logai.analysis.nn_anomaly_detector import NNAnomalyDetector
from logai.information_extraction.log_vectorizer import LogVectorizer
from logai.utils import constants

# %% [markdown]
# ### Loading config from yaml
# While the way to load config from yaml file is generic across all datasets, dive into the yaml file itself to specify particular nuances of your dataset (for e.g. regex patterns or mapping of column names to the LogRecordObject attributes)

# %%
config_path = "configs/bgl_cnn_unsupervised_parsed_sequential_config.yaml"
config_parsed = read_file(config_path)
config_dict = config_parsed["workflow_config"]
validate_config_dict(config_dict)
config = OpenSetADWorkflowConfig.from_dict(config_dict)

# %%
dataloader = FileDataLoader(config.data_loader_config)
logrecord = dataloader.load_data()
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 358455    RAS KERNEL FATAL idoproxy communication failur...
# 358456    RAS KERNEL FATAL idoproxy communication failur...
# 358457    RAS KERNEL FATAL idoproxy communication failur...
# 358458    RAS KERNEL FATAL idoproxy communication failur...
# 358459    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 358460, dtype: object
# /Users/alexander.huang/Workspace/logai/logai/dataloader/data_loader.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[constants.LOG_TIMESTAMPS] = pd.to_datetime(

# %% [markdown]
# ### Preprocessing loaded data using BGLPreprocessor
# This is the only part of the workflow that differs based on the dataset used. Each dataset must have its own Preprocessor class implemented. The main functionalities of the preprocessor class is to help process the raw log data and extract the standard fields of the LogRecordObject (e.g. body, labels, timestamps, span_ids, attributes etc).
#
# For some of the fields (like timestamp) where the extraction is generic, it is already automatically handled in the DataLoader class.
#
# Whereas, for some of the more dataset-specific fields (e.g. span_ids or labels), the custom extraction code has to be implemented in the dataset's corresponding Preprocessor class. For e.g. raw BGL dataset does not have any id associated with the loglines. But most existing log anomaly detection literature does a fixed time-partitioning of the logs and uses these partition indices as ids of the log segments.
#
# If you want to use a different time-partitioning or a different scheme for id-ing the loglines in BGL dataset, you have to write your own custom Preprocessor for BGL to serve that purpose.

# %%
preprocessor = BGLPreprocessor(config.preprocessor_config)
preprocessed_filepath = os.path.join(config.output_dir, 'BGL_11k_processed.csv')            
logrecord = preprocessor.clean_log(logrecord)
logrecord.save_to_csv(preprocessed_filepath)
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 358455    RAS KERNEL FATAL idoproxy communication failur...
# 358456    RAS KERNEL FATAL idoproxy communication failur...
# 358457    RAS KERNEL FATAL idoproxy communication failur...
# 358458    RAS KERNEL FATAL idoproxy communication failur...
# 358459    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 358460, dtype: object

# %%
parser = LogParser(config.log_parser_config)
parsed_result = parser.parse(logrecord.body[constants.LOGLINE_NAME])
logrecord.body[constants.LOGLINE_NAME] = parsed_result[constants.PARSED_LOGLINE_NAME]
parsed_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed.csv')
logrecord.save_to_csv(parsed_filepath)
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 358455    RAS KERNEL FATAL idoproxy communication failur...
# 358456    RAS KERNEL FATAL idoproxy communication failur...
# 358457    RAS KERNEL FATAL idoproxy communication failur...
# 358458    RAS KERNEL FATAL idoproxy communication failur...
# 358459    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 358460, dtype: object

# %%
partitioner = OpenSetPartitioner(config.open_set_partitioner_config)
partitioned_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10.csv')
logrecord = partitioner.partition(logrecord)
logrecord.save_to_csv(partitioned_filepath)
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 346567    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346568    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346569    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346570    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346571    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 346572, dtype: object

# %%
train_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10_unsupervised_train.csv')
dev_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10_unsupervised_dev.csv')
test_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10_unsupervised_test.csv')

(train_data, dev_data, test_data) = split_train_dev_test_for_anomaly_detection(
                logrecord,training_type=config.training_type,
                test_data_frac_neg_class=config.test_data_frac_neg,
                test_data_frac_pos_class=config.test_data_frac_pos,
                shuffle=config.train_test_shuffle
            )

train_data.save_to_csv(train_filepath)
dev_data.save_to_csv(dev_filepath)
test_data.save_to_csv(test_filepath)
print ('Train/Dev/Test Anomalous', len(train_data.labels[train_data.labels[constants.LABELS]==1]), 
                                   len(dev_data.labels[dev_data.labels[constants.LABELS]==1]), 
                                   len(test_data.labels[test_data.labels[constants.LABELS]==1]))
print ('Train/Dev/Test Normal', len(train_data.labels[train_data.labels[constants.LABELS]==0]), 
                                   len(dev_data.labels[dev_data.labels[constants.LABELS]==0]), 
                                   len(test_data.labels[test_data.labels[constants.LABELS]==0]))
# Out:
# indices_train/dev/test:  9503 1941 336941
# Train/Dev/Test Anomalous 0 0 336941
# Train/Dev/Test Normal 9503 1941 0

# %%
vectorizer = LogVectorizer(config.log_vectorizer_config)
vectorizer.fit(train_data)
train_features = vectorizer.transform(train_data)
dev_features = vectorizer.transform(dev_data)
test_features = vectorizer.transform(test_data)

# %%
anomaly_detector = NNAnomalyDetector(config=config.nn_anomaly_detection_config)
anomaly_detector.fit(train_features, dev_features)
# Out:
# INFO:root:Start training on 2376 batches with cpu.
# INFO:root:Batch 100, training loss : 0.5498798630386591
# INFO:root:Batch 200, training loss : 0.2851734692277387
# INFO:root:Batch 300, training loss : 0.19262694320331017
# INFO:root:Batch 400, training loss : 0.15035048295889283
# INFO:root:Batch 500, training loss : 0.12030114698326361
# INFO:root:Batch 600, training loss : 0.10025550954896668
# INFO:root:Batch 700, training loss : 0.13805717022758343
# INFO:root:Batch 800, training loss : 0.12090422266531618
# INFO:root:Batch 900, training loss : 0.10749230805376506
# INFO:root:Batch 1000, training loss : 0.09675072839219774
# INFO:root:Batch 1100, training loss : 0.08795906288264467
# INFO:root:Batch 1200, training loss : 0.12008622003599081
# INFO:root:Batch 1300, training loss : 0.1419812561137832
# INFO:root:Batch 1400, training loss : 0.13202175139462985
# INFO:root:Batch 1500, training loss : 0.1233312676284786
# INFO:root:Batch 1600, training loss : 0.11569821562447885
# INFO:root:Batch 1700, training loss : 0.10894661523392268
# INFO:root:Batch 1800, training loss : 0.10293476200074766
# INFO:root:Batch 1900, training loss : 0.09754872635032132
# INFO:root:Batch 2000, training loss : 0.09269635702268669
# INFO:root:Batch 2100, training loss : 0.08830251183056567
# INFO:root:Batch 2200, training loss : 0.08430539839621196
# INFO:root:Batch 2300, training loss : 0.08065377563193184
# INFO:root:Epoch 1/10, training loss: 0.07808299596831947 [3.5982658863067627s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.032374547953514285
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_cnn/model.ckpt
# INFO:root:Batch 100, training loss : 4.295052279985612e-06
# INFO:root:Batch 200, training loss : 2.2935574985183394e-06
# INFO:root:Batch 300, training loss : 1.5727484021018276e-06
# INFO:root:Batch 400, training loss : 0.012345267519581888
# INFO:root:Batch 500, training loss : 0.009876399028397402
# INFO:root:Batch 600, training loss : 0.008230430672618378
# INFO:root:Batch 700, training loss : 0.035764587952882544
# INFO:root:Batch 800, training loss : 0.031302578749605646
# INFO:root:Batch 900, training loss : 0.027827588101170544
# INFO:root:Batch 1000, training loss : 0.02504527084105031
# INFO:root:Batch 1100, training loss : 0.022768539443746117
# INFO:root:Batch 1200, training loss : 0.03197753347870964
# INFO:root:Batch 1300, training loss : 0.03878528834818524
# INFO:root:Batch 1400, training loss : 0.03601993645802335
# INFO:root:Batch 1500, training loss : 0.03362123388622729
# INFO:root:Batch 1600, training loss : 0.031521576942464595
# INFO:root:Batch 1700, training loss : 0.029668530425900976
# INFO:root:Batch 1800, training loss : 0.02802113677089694
# INFO:root:Batch 1900, training loss : 0.02654699762796414
# INFO:root:Batch 2000, training loss : 0.025220164277738186
# INFO:root:Batch 2100, training loss : 0.024019620566762906
# INFO:root:Batch 2200, training loss : 0.022928157209691016
# INFO:root:Batch 2300, training loss : 0.021931562764235732
# INFO:root:Epoch 2/10, training loss: 0.021230233215292067 [3.104919910430908s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.049435033641007986
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Batch 100, training loss : 3.0994410451512525e-08
# INFO:root:Batch 200, training loss : 1.5497205225756263e-08
# INFO:root:Batch 300, training loss : 1.0331470150504173e-08
# INFO:root:Batch 400, training loss : 0.013320088982580884
# INFO:root:Batch 500, training loss : 0.010656071186064707
# INFO:root:Batch 600, training loss : 0.00888005932172059
# INFO:root:Batch 700, training loss : 0.0452711531160181
# INFO:root:Batch 800, training loss : 0.039618026784790705
# INFO:root:Batch 900, training loss : 0.03522047422332204
# INFO:root:Batch 1000, training loss : 0.031699081376337715
# INFO:root:Batch 1100, training loss : 0.028817497667938778
# INFO:root:Batch 1200, training loss : 0.033148761414894326
# INFO:root:Batch 1300, training loss : 0.038346705917420995
# INFO:root:Batch 1400, training loss : 0.03560774243232164
# INFO:root:Batch 1500, training loss : 0.033233936249528764
# INFO:root:Batch 1600, training loss : 0.031156840267879193
# INFO:root:Batch 1700, training loss : 0.02932409905274767
# INFO:root:Batch 1800, training loss : 0.027694990054854613
# INFO:root:Batch 1900, training loss : 0.02623736527350871
# INFO:root:Batch 2000, training loss : 0.024925502970297397
# INFO:root:Batch 2100, training loss : 0.02373857993405859
# INFO:root:Batch 2200, training loss : 0.02265955899202331
# INFO:root:Batch 2300, training loss : 0.0216743659579911
# INFO:root:Epoch 3/10, training loss: 0.020981079211605413 [3.690135955810547s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.0267718841586216
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_cnn/model.ckpt
# INFO:root:Batch 100, training loss : 3.576277897821001e-08
# INFO:root:Batch 200, training loss : 1.7881389489105005e-08
# INFO:root:Batch 300, training loss : 1.1920926326070003e-08
# INFO:root:Batch 400, training loss : 0.013181199431417401
# INFO:root:Batch 500, training loss : 0.01054495954513392
# INFO:root:Batch 600, training loss : 0.0087874662876116
# INFO:root:Batch 700, training loss : 0.039105066518395945
# INFO:root:Batch 800, training loss : 0.03421711201740288
# INFO:root:Batch 900, training loss : 0.03041534932907206
# INFO:root:Batch 1000, training loss : 0.027373842291133967
# INFO:root:Batch 1100, training loss : 0.024885312257478902
# INFO:root:Batch 1200, training loss : 0.028700921599575047
# INFO:root:Batch 1300, training loss : 0.0337236886919761
# INFO:root:Batch 1400, training loss : 0.03131485540324665
# INFO:root:Batch 1500, training loss : 0.029227198376363537
# INFO:root:Batch 1600, training loss : 0.027400498477840814
# INFO:root:Batch 1700, training loss : 0.02578870444973253
# INFO:root:Batch 1800, training loss : 0.024355998646969614
# INFO:root:Batch 1900, training loss : 0.023074103981339633
# INFO:root:Batch 2000, training loss : 0.021920398782272654
# INFO:root:Batch 2100, training loss : 0.020876570268831097
# INFO:root:Batch 2200, training loss : 0.019927635256611502
# INFO:root:Batch 2300, training loss : 0.019061216332411004
# INFO:root:Epoch 4/10, training loss: 0.01845151412649213 [3.3569462299346924s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.023042454671712568
# INFO:root:Dev acc @ top-1: 0.9948480164863472  correct: 1931 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_cnn/model.ckpt
# INFO:root:Batch 100, training loss : 0.0
# INFO:root:Batch 200, training loss : 0.0
# INFO:root:Batch 300, training loss : 0.0
# INFO:root:Batch 400, training loss : 0.013309998512268066
# INFO:root:Batch 500, training loss : 0.010647998809814454
# INFO:root:Batch 600, training loss : 0.008873332341512044
# INFO:root:Batch 700, training loss : 0.04386712163854806
# INFO:root:Batch 800, training loss : 0.03838407415995526
# INFO:root:Batch 900, training loss : 0.03411939664081773
# INFO:root:Batch 1000, training loss : 0.030707472712360413
# INFO:root:Batch 1100, training loss : 0.02791588428396401
# INFO:root:Batch 1200, training loss : 0.03092954545716452
# INFO:root:Batch 1300, training loss : 0.036255850580865764
# INFO:root:Batch 1400, training loss : 0.033666146967946786
# INFO:root:Batch 1500, training loss : 0.03142173717008367
# INFO:root:Batch 1600, training loss : 0.029457878596953434
# INFO:root:Batch 1700, training loss : 0.02772506220889735
# INFO:root:Batch 1800, training loss : 0.02618478097506972
# INFO:root:Batch 1900, training loss : 0.024806634607960787
# INFO:root:Batch 2000, training loss : 0.02356630287756275
# INFO:root:Batch 2100, training loss : 0.02244409797863119
# INFO:root:Batch 2200, training loss : 0.021423911706875225
# INFO:root:Batch 2300, training loss : 0.020492437284837173
# INFO:root:Epoch 5/10, training loss: 0.019836955284143726 [3.3957228660583496s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.035240033299397726
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Batch 100, training loss : 0.0
# INFO:root:Batch 200, training loss : 0.0
# INFO:root:Batch 300, training loss : 0.0
# INFO:root:Batch 400, training loss : 0.013385249376296997
# INFO:root:Batch 500, training loss : 0.010708199501037598
# INFO:root:Batch 600, training loss : 0.008923499584197999
# INFO:root:Batch 700, training loss : 0.0423515331225298
# INFO:root:Batch 800, training loss : 0.0370576957902993
# INFO:root:Batch 900, training loss : 0.03294026599250549
# INFO:root:Batch 1000, training loss : 0.029646322839723523
# INFO:root:Batch 1100, training loss : 0.026951278441992823
# INFO:root:Batch 1200, training loss : 0.030910978654674726
# INFO:root:Batch 1300, training loss : 0.036151369553143235
# INFO:root:Batch 1400, training loss : 0.033569128870775865
# INFO:root:Batch 1500, training loss : 0.03133118694605747
# INFO:root:Batch 1600, training loss : 0.02937298776192888
# INFO:root:Batch 1700, training loss : 0.027645164952403652
# INFO:root:Batch 1800, training loss : 0.026109322455047893
# INFO:root:Batch 1900, training loss : 0.02473514758899274
# INFO:root:Batch 2000, training loss : 0.023498390209543103
# INFO:root:Batch 2100, training loss : 0.022379419247183906
# INFO:root:Batch 2200, training loss : 0.02136217291776646
# INFO:root:Batch 2300, training loss : 0.020433382790907048
# INFO:root:Epoch 6/10, training loss: 0.019779789738672646 [3.3837199211120605s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.022546088994900338
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_cnn/model.ckpt
# INFO:root:Batch 100, training loss : 3.4570687716950486e-08
# INFO:root:Batch 200, training loss : 1.7285343858475243e-08
# INFO:root:Batch 300, training loss : 1.152356257231683e-08
# INFO:root:Batch 400, training loss : 0.012677451968190976
# INFO:root:Batch 500, training loss : 0.010141985416409269
# INFO:root:Batch 600, training loss : 0.008451674381888132
# INFO:root:Batch 700, training loss : 0.039682021231724054
# INFO:root:Batch 800, training loss : 0.034722437638087966
# INFO:root:Batch 900, training loss : 0.030864938863095073
# INFO:root:Batch 1000, training loss : 0.02777862617471662
# INFO:root:Batch 1100, training loss : 0.02525335450151445
# INFO:root:Batch 1200, training loss : 0.027527746845951634
# INFO:root:Batch 1300, training loss : 0.03256305119896787
# INFO:root:Batch 1400, training loss : 0.03023711897047017
# INFO:root:Batch 1500, training loss : 0.028221311039105492
# INFO:root:Batch 1600, training loss : 0.026457479099161397
# INFO:root:Batch 1700, training loss : 0.02490115679921073
# INFO:root:Batch 1800, training loss : 0.023517759199254577
# INFO:root:Batch 1900, training loss : 0.02227998239929381
# INFO:root:Batch 2000, training loss : 0.021165983279329118
# INFO:root:Batch 2100, training loss : 0.02015807931364678
# INFO:root:Batch 2200, training loss : 0.01924180298120829
# INFO:root:Batch 2300, training loss : 0.018405202851590537
# INFO:root:Epoch 7/10, training loss: 0.017816484241859526 [3.4484243392944336s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.036373850346951064
# INFO:root:Dev acc @ top-1: 0.9927872230808862  correct: 1927 out of 1941
# INFO:root:Batch 100, training loss : 1.5497206291570365e-08
# INFO:root:Batch 200, training loss : 7.748603145785183e-09
# INFO:root:Batch 300, training loss : 5.165735430523455e-09
# INFO:root:Batch 400, training loss : 0.012909552156924438
# INFO:root:Batch 500, training loss : 0.01032766556739604
# INFO:root:Batch 600, training loss : 0.008606407841043773
# INFO:root:Batch 700, training loss : 0.04210190021335165
# INFO:root:Batch 800, training loss : 0.03683975470841119
# INFO:root:Batch 900, training loss : 0.032746847715138
# INFO:root:Batch 1000, training loss : 0.029472228270289405
# INFO:root:Batch 1100, training loss : 0.026792949096285667
# INFO:root:Batch 1200, training loss : 0.029586417580165333
# INFO:root:Batch 1300, training loss : 0.03451023039244994
# INFO:root:Batch 1400, training loss : 0.032045213935846376
# INFO:root:Batch 1500, training loss : 0.029908866340123286
# INFO:root:Batch 1600, training loss : 0.02803956219386558
# INFO:root:Batch 1700, training loss : 0.026390176182461724
# INFO:root:Batch 1800, training loss : 0.024924055283436074
# INFO:root:Batch 1900, training loss : 0.023612262900097332
# INFO:root:Batch 2000, training loss : 0.022431649755092466
# INFO:root:Batch 2100, training loss : 0.02136347595723092
# INFO:root:Batch 2200, training loss : 0.020392408868265877
# INFO:root:Batch 2300, training loss : 0.019505782395732578
# INFO:root:Epoch 8/10, training loss: 0.018881860063209147 [3.535597085952759s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.02516569708590875
# INFO:root:Dev acc @ top-1: 0.9948480164863472  correct: 1931 out of 1941
# INFO:root:Batch 100, training loss : 2.3841856489070778e-09
# INFO:root:Batch 200, training loss : 1.1920928244535389e-09
# INFO:root:Batch 300, training loss : 7.947285496356927e-10
# INFO:root:Batch 400, training loss : 0.013356324732303247
# INFO:root:Batch 500, training loss : 0.010685083627699087
# INFO:root:Batch 600, training loss : 0.008904256224629646
# INFO:root:Batch 700, training loss : 0.041009404793779396
# INFO:root:Batch 800, training loss : 0.0358834123296919
# INFO:root:Batch 900, training loss : 0.0318965237720905
# INFO:root:Batch 1000, training loss : 0.02870701444592659
# INFO:root:Batch 1100, training loss : 0.02609741189657475
# INFO:root:Batch 1200, training loss : 0.02843734438339047
# INFO:root:Batch 1300, training loss : 0.033351930860376
# INFO:root:Batch 1400, training loss : 0.03096965008463486
# INFO:root:Batch 1500, training loss : 0.0289050067456592
# INFO:root:Batch 1600, training loss : 0.027098443824055504
# INFO:root:Batch 1700, training loss : 0.02550441771675812
# INFO:root:Batch 1800, training loss : 0.02408750562138267
# INFO:root:Batch 1900, training loss : 0.022819742167625685
# INFO:root:Batch 2000, training loss : 0.021678755059244402
# INFO:root:Batch 2100, training loss : 0.020646433389756573
# INFO:root:Batch 2200, training loss : 0.01970795914476764
# INFO:root:Batch 2300, training loss : 0.018851091355864696
# INFO:root:Epoch 9/10, training loss: 0.018248110319229294 [3.468402147293091s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.029182633768741726
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Batch 100, training loss : 5.483625507451961e-08
# INFO:root:Batch 200, training loss : 2.7418127537259805e-08
# INFO:root:Batch 300, training loss : 1.827875169150654e-08
# INFO:root:Batch 400, training loss : 0.012586625516406914
# INFO:root:Batch 500, training loss : 0.01006939244267592
# INFO:root:Batch 600, training loss : 0.008391239841737352
# INFO:root:Batch 700, training loss : 0.04094653962346891
# INFO:root:Batch 800, training loss : 0.03583577578742319
# INFO:root:Batch 900, training loss : 0.03185761762949505
# INFO:root:Batch 1000, training loss : 0.028671961843536826
# INFO:root:Batch 1100, training loss : 0.02606545366984413
# INFO:root:Batch 1200, training loss : 0.027777536648206938
# INFO:root:Batch 1300, training loss : 0.03239089894274352
# INFO:root:Batch 1400, training loss : 0.030077263303976132
# INFO:root:Batch 1500, training loss : 0.02807211241704439
# INFO:root:Batch 1600, training loss : 0.026317605390979115
# INFO:root:Batch 1700, training loss : 0.02476951095621564
# INFO:root:Batch 1800, training loss : 0.023393427014203657
# INFO:root:Batch 1900, training loss : 0.022162194013456097
# INFO:root:Batch 2000, training loss : 0.021054084312783293
# INFO:root:Batch 2100, training loss : 0.020051508869317423
# INFO:root:Batch 2200, training loss : 0.01914007664798481
# INFO:root:Batch 2300, training loss : 0.018307899402420252
# INFO:root:Epoch 10/10, training loss: 0.01772229319257853 [3.3577699661254883s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.05256094123345705
# INFO:root:Dev acc @ top-1: 0.9948480164863472  correct: 1931 out of 1941
# INFO:root:Loading model from temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_cnn/model.ckpt

# %%
predict_results = anomaly_detector.predict(test_features)
print (predict_results)
# Out:
# INFO:root:Evaluating test data.
# INFO:root:Finish inference. [27.80745768547058s]
# INFO:root:Calculating acc sum.
# INFO:root:Finish generating store_df.
# INFO:root:Finish counting [2.5750577449798584s]
# INFO:root:Best result: f1: 1.0 rc: 1.0 pc: 1.0
# {'f1': 1.0, 'rc': 1.0, 'pc': 1.0, 'pred': 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1803    1
# 1804    1
# 1805    1
# 1806    1
# 1807    1
# Name: window_pred_anomaly_8, Length: 1808, dtype: int64, 'true': 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1803    1
# 1804    1
# 1805    1
# 1806    1
# 1807    1
# Name: window_anomalies, Length: 1808, dtype: int64}
