# %% [markdown]
# ### Log Anomaly Detection on BGL Dataset using Transformer based models
# This is a running example of an end-to-end workflow for Log Anomaly Detection on public dataset BGL using Transformer based neural anomaly detectors.
#
# It is very similar to that on the HDFS dataset. We will only mark out the dataset specific portions of this workflow i.e. the parts that differ between the two datasets.
#
# For a more complete elaboration of the full workflow please refer to `hdfs_lstm_unsupervised_parsed_sequential.ipynb` notebook.

# %%
import os 
from logai.applications.openset.anomaly_detection.openset_anomaly_detection_workflow import OpenSetADWorkflowConfig, validate_config_dict
from logai.utils.file_utils import read_file
from logai.utils.dataset_utils import split_train_dev_test_for_anomaly_detection
import logging 
from logai.dataloader.data_loader import FileDataLoader
from logai.preprocess.bgl_preprocessor import BGLPreprocessor
from logai.information_extraction.log_parser import LogParser
from logai.preprocess.openset_partitioner import OpenSetPartitioner
from logai.analysis.nn_anomaly_detector import NNAnomalyDetector
from logai.information_extraction.log_vectorizer import LogVectorizer
from logai.utils import constants

# %% [markdown]
# ### Loading config from yaml
# While the way to load config from yaml file is generic across all datasets, dive into the yaml file itself to specify particular nuances of your dataset (for e.g. regex patterns or mapping of column names to the LogRecordObject attributes)

# %%
config_path = "configs/bgl_transformer_unsupervised_parsed_sequential_config.yaml"
config_parsed = read_file(config_path)
config_dict = config_parsed["workflow_config"]
validate_config_dict(config_dict)
config = OpenSetADWorkflowConfig.from_dict(config_dict)

# %%
dataloader = FileDataLoader(config.data_loader_config)
logrecord = dataloader.load_data()
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 358455    RAS KERNEL FATAL idoproxy communication failur...
# 358456    RAS KERNEL FATAL idoproxy communication failur...
# 358457    RAS KERNEL FATAL idoproxy communication failur...
# 358458    RAS KERNEL FATAL idoproxy communication failur...
# 358459    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 358460, dtype: object
# /Users/alexander.huang/Workspace/logai/logai/dataloader/data_loader.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[constants.LOG_TIMESTAMPS] = pd.to_datetime(

# %% [markdown]
# ### Preprocessing loaded data using BGLPreprocessor
# This is the only part of the workflow that differs based on the dataset used. Each dataset must have its own Preprocessor class implemented. The main functionalities of the preprocessor class is to help process the raw log data and extract the standard fields of the LogRecordObject (e.g. body, labels, timestamps, span_ids, attributes etc).
#
# For some of the fields (like timestamp) where the extraction is generic, it is already automatically handled in the DataLoader class.
#
# Whereas, for some of the more dataset-specific fields (e.g. span_ids or labels), the custom extraction code has to be implemented in the dataset's corresponding Preprocessor class. For e.g. raw BGL dataset does not have any id associated with the loglines. But most existing log anomaly detection literature does a fixed time-partitioning of the logs and uses these partition indices as ids of the log segments.
#
# If you want to use a different time-partitioning or a different scheme for id-ing the loglines in BGL dataset, you have to write your own custom Preprocessor for BGL to serve that purpose.

# %%
preprocessor = BGLPreprocessor(config.preprocessor_config)
preprocessed_filepath = os.path.join(config.output_dir, 'BGL_11k_processed.csv')            
logrecord = preprocessor.clean_log(logrecord)
logrecord.save_to_csv(preprocessed_filepath)
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 358455    RAS KERNEL FATAL idoproxy communication failur...
# 358456    RAS KERNEL FATAL idoproxy communication failur...
# 358457    RAS KERNEL FATAL idoproxy communication failur...
# 358458    RAS KERNEL FATAL idoproxy communication failur...
# 358459    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 358460, dtype: object

# %%
parser = LogParser(config.log_parser_config)
parsed_result = parser.parse(logrecord.body[constants.LOGLINE_NAME])
logrecord.body[constants.LOGLINE_NAME] = parsed_result[constants.PARSED_LOGLINE_NAME]
parsed_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed.csv')
logrecord.save_to_csv(parsed_filepath)
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 358455    RAS KERNEL FATAL idoproxy communication failur...
# 358456    RAS KERNEL FATAL idoproxy communication failur...
# 358457    RAS KERNEL FATAL idoproxy communication failur...
# 358458    RAS KERNEL FATAL idoproxy communication failur...
# 358459    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 358460, dtype: object

# %%
partitioner = OpenSetPartitioner(config.open_set_partitioner_config)
partitioned_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10.csv')
logrecord = partitioner.partition(logrecord)
logrecord.save_to_csv(partitioned_filepath)
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 346567    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346568    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346569    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346570    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346571    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 346572, dtype: object

# %%
train_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10_unsupervised_train.csv')
dev_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10_unsupervised_dev.csv')
test_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10_unsupervised_test.csv')

(train_data, dev_data, test_data) = split_train_dev_test_for_anomaly_detection(
                logrecord,training_type=config.training_type,
                test_data_frac_neg_class=config.test_data_frac_neg,
                test_data_frac_pos_class=config.test_data_frac_pos,
                shuffle=config.train_test_shuffle
            )

train_data.save_to_csv(train_filepath)
dev_data.save_to_csv(dev_filepath)
test_data.save_to_csv(test_filepath)
print ('Train/Dev/Test Anomalous', len(train_data.labels[train_data.labels[constants.LABELS]==1]), 
                                   len(dev_data.labels[dev_data.labels[constants.LABELS]==1]), 
                                   len(test_data.labels[test_data.labels[constants.LABELS]==1]))
print ('Train/Dev/Test Normal', len(train_data.labels[train_data.labels[constants.LABELS]==0]), 
                                   len(dev_data.labels[dev_data.labels[constants.LABELS]==0]), 
                                   len(test_data.labels[test_data.labels[constants.LABELS]==0]))
# Out:
# indices_train/dev/test:  9503 1941 336941
# Train/Dev/Test Anomalous 0 0 336941
# Train/Dev/Test Normal 9503 1941 0

# %%
vectorizer = LogVectorizer(config.log_vectorizer_config)
vectorizer.fit(train_data)
train_features = vectorizer.transform(train_data)
dev_features = vectorizer.transform(dev_data)
test_features = vectorizer.transform(test_data)

# %%
anomaly_detector = NNAnomalyDetector(config=config.nn_anomaly_detection_config)
anomaly_detector.fit(train_features, dev_features)
# Out:
# INFO:root:Start training on 2376 batches with cpu.
# INFO:root:Batch 100, training loss : 1.0404542474448681
# INFO:root:Batch 200, training loss : 0.5543089779000729
# INFO:root:Batch 300, training loss : 0.37636344133876265
# INFO:root:Batch 400, training loss : 0.2897787929698825
# INFO:root:Batch 500, training loss : 0.23332228877115996
# INFO:root:Batch 600, training loss : 0.1953077235375531
# INFO:root:Batch 700, training loss : 0.19556429206526704
# INFO:root:Batch 800, training loss : 0.1717436073400313
# INFO:root:Batch 900, training loss : 0.15308049101434235
# INFO:root:Batch 1000, training loss : 0.13807085038139486
# INFO:root:Batch 1100, training loss : 0.12574026073964142
# INFO:root:Batch 1200, training loss : 0.16344954730710015
# INFO:root:Batch 1300, training loss : 0.2125207525699471
# INFO:root:Batch 1400, training loss : 0.19880436461352344
# INFO:root:Batch 1500, training loss : 0.18619176580384372
# INFO:root:Batch 1600, training loss : 0.17493333072343376
# INFO:root:Batch 1700, training loss : 0.1648963218357633
# INFO:root:Batch 1800, training loss : 0.1559172666428559
# INFO:root:Batch 1900, training loss : 0.14784798052456033
# INFO:root:Batch 2000, training loss : 0.14056210860126886
# INFO:root:Batch 2100, training loss : 0.1339536723165795
# INFO:root:Batch 2200, training loss : 0.12793401816251307
# INFO:root:Batch 2300, training loss : 0.122428808999096
# INFO:root:Epoch 1/10, training loss: 0.11855001550221499 [7.941935300827026s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.10888895317131209
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 0.0006276542735577095
# INFO:root:Batch 200, training loss : 0.00036536022005748234
# INFO:root:Batch 300, training loss : 0.000258550188979522
# INFO:root:Batch 400, training loss : 0.008336083263843648
# INFO:root:Batch 500, training loss : 0.006676343039067433
# INFO:root:Batch 600, training loss : 0.005568757636265218
# INFO:root:Batch 700, training loss : 0.036351251112251445
# INFO:root:Batch 800, training loss : 0.03183299532884121
# INFO:root:Batch 900, training loss : 0.028315567293013575
# INFO:root:Batch 1000, training loss : 0.02549961491393333
# INFO:root:Batch 1100, training loss : 0.023194331500748046
# INFO:root:Batch 1200, training loss : 0.0410816885573513
# INFO:root:Batch 1300, training loss : 0.04882814500743944
# INFO:root:Batch 1400, training loss : 0.045378460310364195
# INFO:root:Batch 1500, training loss : 0.04237760501773058
# INFO:root:Batch 1600, training loss : 0.03974618672101315
# INFO:root:Batch 1700, training loss : 0.037420975243328616
# INFO:root:Batch 1800, training loss : 0.0353519264563349
# INFO:root:Batch 1900, training loss : 0.03349915449182031
# INFO:root:Batch 2000, training loss : 0.03183056350807601
# INFO:root:Batch 2100, training loss : 0.03032006713778953
# INFO:root:Batch 2200, training loss : 0.028946260668113115
# INFO:root:Batch 2300, training loss : 0.027691423651874925
# INFO:root:Epoch 2/10, training loss: 0.026808121513237314 [7.320021867752075s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.05818150593789183
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 2.4268045249300484e-05
# INFO:root:Batch 200, training loss : 1.4328660523688085e-05
# INFO:root:Batch 300, training loss : 1.0294318657694627e-05
# INFO:root:Batch 400, training loss : 0.009446265920879852
# INFO:root:Batch 500, training loss : 0.00755750793148286
# INFO:root:Batch 600, training loss : 0.006298282691861346
# INFO:root:Batch 700, training loss : 0.03276164633523146
# INFO:root:Batch 800, training loss : 0.02871532921555442
# INFO:root:Batch 900, training loss : 0.025540868675798644
# INFO:root:Batch 1000, training loss : 0.022996287100473977
# INFO:root:Batch 1100, training loss : 0.02091205400664659
# INFO:root:Batch 1200, training loss : 0.032010826006728145
# INFO:root:Batch 1300, training loss : 0.03872508379489029
# INFO:root:Batch 1400, training loss : 0.035963122388669146
# INFO:root:Batch 1500, training loss : 0.033568984393284075
# INFO:root:Batch 1600, training loss : 0.031473793734916385
# INFO:root:Batch 1700, training loss : 0.029624846257503484
# INFO:root:Batch 1800, training loss : 0.02798113831712947
# INFO:root:Batch 1900, training loss : 0.02651028669585272
# INFO:root:Batch 2000, training loss : 0.02518638362746532
# INFO:root:Batch 2100, training loss : 0.02398844860880645
# INFO:root:Batch 2200, training loss : 0.022899318374619962
# INFO:root:Batch 2300, training loss : 0.02190480944439885
# INFO:root:Epoch 3/10, training loss: 0.021204919035717487 [7.15333104133606s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.03254980140769072
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 4.626474071756092e-06
# INFO:root:Batch 200, training loss : 2.7251049621668244e-06
# INFO:root:Batch 300, training loss : 1.9633640355702177e-06
# INFO:root:Batch 400, training loss : 0.01009677587956233
# INFO:root:Batch 500, training loss : 0.008077759257739557
# INFO:root:Batch 600, training loss : 0.006731684797015021
# INFO:root:Batch 700, training loss : 0.027959738627545465
# INFO:root:Batch 800, training loss : 0.024532365269736615
# INFO:root:Batch 900, training loss : 0.02183007346856136
# INFO:root:Batch 1000, training loss : 0.01966169202418206
# INFO:root:Batch 1100, training loss : 0.01788455720486442
# INFO:root:Batch 1200, training loss : 0.026649262590243788
# INFO:root:Batch 1300, training loss : 0.03323771622855566
# INFO:root:Batch 1400, training loss : 0.03086499518767259
# INFO:root:Batch 1500, training loss : 0.02880852696389703
# INFO:root:Batch 1600, training loss : 0.027009029874288226
# INFO:root:Batch 1700, training loss : 0.025421168763620654
# INFO:root:Batch 1800, training loss : 0.024009681962247068
# INFO:root:Batch 1900, training loss : 0.022746722212513167
# INFO:root:Batch 2000, training loss : 0.021610016655453732
# INFO:root:Batch 2100, training loss : 0.02058153005631184
# INFO:root:Batch 2200, training loss : 0.0196465146043543
# INFO:root:Batch 2300, training loss : 0.018792772554060762
# INFO:root:Epoch 4/10, training loss: 0.018191972565767343 [7.268567800521851s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.023809160854302774
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 5.872125277619489e-06
# INFO:root:Batch 200, training loss : 3.228721361949738e-06
# INFO:root:Batch 300, training loss : 2.2796374574340917e-06
# INFO:root:Batch 400, training loss : 0.009881428149883433
# INFO:root:Batch 500, training loss : 0.007906217784748095
# INFO:root:Batch 600, training loss : 0.006589183782080709
# INFO:root:Batch 700, training loss : 0.023253735585918898
# INFO:root:Batch 800, training loss : 0.02042741316318196
# INFO:root:Batch 900, training loss : 0.018188445722046476
# INFO:root:Batch 1000, training loss : 0.01638827686418014
# INFO:root:Batch 1100, training loss : 0.014911269600298815
# INFO:root:Batch 1200, training loss : 0.022753567100640238
# INFO:root:Batch 1300, training loss : 0.02948334915500532
# INFO:root:Batch 1400, training loss : 0.027378013315695345
# INFO:root:Batch 1500, training loss : 0.02555335665591366
# INFO:root:Batch 1600, training loss : 0.02395674393192307
# INFO:root:Batch 1700, training loss : 0.02254794717258497
# INFO:root:Batch 1800, training loss : 0.021295665505232476
# INFO:root:Batch 1900, training loss : 0.020175181816930954
# INFO:root:Batch 2000, training loss : 0.01916673064272594
# INFO:root:Batch 2100, training loss : 0.018254302172034005
# INFO:root:Batch 2200, training loss : 0.01742480798095418
# INFO:root:Batch 2300, training loss : 0.01666743527127238
# INFO:root:Epoch 5/10, training loss: 0.01613446237065728 [7.5153648853302s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.020853958199572264
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 6.999791112320963e-06
# INFO:root:Batch 200, training loss : 3.806859382962102e-06
# INFO:root:Batch 300, training loss : 2.6630759875464114e-06
# INFO:root:Batch 400, training loss : 0.00974497917066735
# INFO:root:Batch 500, training loss : 0.0077976853994686625
# INFO:root:Batch 600, training loss : 0.006499193120528872
# INFO:root:Batch 700, training loss : 0.020317455049442115
# INFO:root:Batch 800, training loss : 0.017849145074058548
# INFO:root:Batch 900, training loss : 0.015897913615018872
# INFO:root:Batch 1000, training loss : 0.014328194472333479
# INFO:root:Batch 1100, training loss : 0.013039642005386312
# INFO:root:Batch 1200, training loss : 0.020330690818317385
# INFO:root:Batch 1300, training loss : 0.02732908892362395
# INFO:root:Batch 1400, training loss : 0.025377335477036057
# INFO:root:Batch 1500, training loss : 0.02368579380945507
# INFO:root:Batch 1600, training loss : 0.02220567980020631
# INFO:root:Batch 1700, training loss : 0.020899687734899447
# INFO:root:Batch 1800, training loss : 0.019738795435184517
# INFO:root:Batch 1900, training loss : 0.018700094294002285
# INFO:root:Batch 2000, training loss : 0.017765259869486485
# INFO:root:Batch 2100, training loss : 0.01691945019915323
# INFO:root:Batch 2200, training loss : 0.01615053047471043
# INFO:root:Batch 2300, training loss : 0.015448468255668823
# INFO:root:Epoch 6/10, training loss: 0.014954420809330815 [7.328513860702515s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.02035119434693699
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 7.469444972230121e-06
# INFO:root:Batch 200, training loss : 4.017844470638465e-06
# INFO:root:Batch 300, training loss : 2.769162027126034e-06
# INFO:root:Batch 400, training loss : 0.00973061407014491
# INFO:root:Batch 500, training loss : 0.007786609355480379
# INFO:root:Batch 600, training loss : 0.006490289317456141
# INFO:root:Batch 700, training loss : 0.019247874897593168
# INFO:root:Batch 800, training loss : 0.016901114526405116
# INFO:root:Batch 900, training loss : 0.015055415460823932
# INFO:root:Batch 1000, training loss : 0.013570990193239624
# INFO:root:Batch 1100, training loss : 0.012352318585310745
# INFO:root:Batch 1200, training loss : 0.019171521260381442
# INFO:root:Batch 1300, training loss : 0.026297014329909437
# INFO:root:Batch 1400, training loss : 0.024418834977194288
# INFO:root:Batch 1500, training loss : 0.02279107635927223
# INFO:root:Batch 1600, training loss : 0.02136677900044761
# INFO:root:Batch 1700, training loss : 0.020110042881244832
# INFO:root:Batch 1800, training loss : 0.01899294059857553
# INFO:root:Batch 1900, training loss : 0.01799342508101567
# INFO:root:Batch 2000, training loss : 0.017093860459561953
# INFO:root:Batch 2100, training loss : 0.01627996360700548
# INFO:root:Batch 2200, training loss : 0.015540057377408684
# INFO:root:Batch 2300, training loss : 0.014864489938840281
# INFO:root:Epoch 7/10, training loss: 0.014389087465357954 [7.257369041442871s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.02000987742677828
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 8.262134227834395e-06
# INFO:root:Batch 200, training loss : 4.359352851395215e-06
# INFO:root:Batch 300, training loss : 2.9912711833427843e-06
# INFO:root:Batch 400, training loss : 0.009753756080231142
# INFO:root:Batch 500, training loss : 0.007805689439321213
# INFO:root:Batch 600, training loss : 0.00650659727770441
# INFO:root:Batch 700, training loss : 0.018697204616294455
# INFO:root:Batch 800, training loss : 0.01642332216488967
# INFO:root:Batch 900, training loss : 0.01463214145223699
# INFO:root:Batch 1000, training loss : 0.013190873698060386
# INFO:root:Batch 1100, training loss : 0.012007303371109711
# INFO:root:Batch 1200, training loss : 0.01834307846973843
# INFO:root:Batch 1300, training loss : 0.02545859241177228
# INFO:root:Batch 1400, training loss : 0.023640240223509426
# INFO:root:Batch 1500, training loss : 0.022064319734917643
# INFO:root:Batch 1600, training loss : 0.020685389158388502
# INFO:root:Batch 1700, training loss : 0.01946868570850985
# INFO:root:Batch 1800, training loss : 0.01838717153083994
# INFO:root:Batch 1900, training loss : 0.01741950095081949
# INFO:root:Batch 2000, training loss : 0.016548597428801087
# INFO:root:Batch 2100, training loss : 0.015760637099355865
# INFO:root:Batch 2200, training loss : 0.01504430763062332
# INFO:root:Batch 2300, training loss : 0.014390264311956027
# INFO:root:Epoch 8/10, training loss: 0.01393001160622719 [7.696142196655273s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.019778881343805222
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 9.076309999045406e-06
# INFO:root:Batch 200, training loss : 4.796839091056882e-06
# INFO:root:Batch 300, training loss : 3.2888891395070158e-06
# INFO:root:Batch 400, training loss : 0.009742966812274627
# INFO:root:Batch 500, training loss : 0.007796960036069592
# INFO:root:Batch 600, training loss : 0.006499221249536653
# INFO:root:Batch 700, training loss : 0.018436154007481685
# INFO:root:Batch 800, training loss : 0.016180589814301413
# INFO:root:Batch 900, training loss : 0.014410599968491774
# INFO:root:Batch 1000, training loss : 0.01298822570295183
# INFO:root:Batch 1100, training loss : 0.011820953844539996
# INFO:root:Batch 1200, training loss : 0.01764123585207824
# INFO:root:Batch 1300, training loss : 0.024667241167580622
# INFO:root:Batch 1400, training loss : 0.022905385117403934
# INFO:root:Batch 1500, training loss : 0.021378438915724562
# INFO:root:Batch 1600, training loss : 0.020042360989255114
# INFO:root:Batch 1700, training loss : 0.018863468701193837
# INFO:root:Batch 1800, training loss : 0.01781556444513937
# INFO:root:Batch 1900, training loss : 0.016877965900248527
# INFO:root:Batch 2000, training loss : 0.016034127090637593
# INFO:root:Batch 2100, training loss : 0.015270643720778902
# INFO:root:Batch 2200, training loss : 0.014576566900464482
# INFO:root:Batch 2300, training loss : 0.013942844223453824
# INFO:root:Epoch 9/10, training loss: 0.013496887682348474 [7.387634754180908s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.019866592583882944
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Batch 100, training loss : 8.098850308897454e-06
# INFO:root:Batch 200, training loss : 4.2878436767068705e-06
# INFO:root:Batch 300, training loss : 2.943201036013458e-06
# INFO:root:Batch 400, training loss : 0.009805884451312377
# INFO:root:Batch 500, training loss : 0.007846361940769086
# INFO:root:Batch 600, training loss : 0.006539899955084571
# INFO:root:Batch 700, training loss : 0.01817076056104963
# INFO:root:Batch 800, training loss : 0.015937723682424503
# INFO:root:Batch 900, training loss : 0.014190721299064873
# INFO:root:Batch 1000, training loss : 0.012788460194225387
# INFO:root:Batch 1100, training loss : 0.011638390532162072
# INFO:root:Batch 1200, training loss : 0.016989993535854512
# INFO:root:Batch 1300, training loss : 0.02390169243878541
# INFO:root:Batch 1400, training loss : 0.022194496812719428
# INFO:root:Batch 1500, training loss : 0.02071492504489096
# INFO:root:Batch 1600, training loss : 0.019420294383628137
# INFO:root:Batch 1700, training loss : 0.018277973211925647
# INFO:root:Batch 1800, training loss : 0.017262576614856768
# INFO:root:Batch 1900, training loss : 0.016354063870110926
# INFO:root:Batch 2000, training loss : 0.01553640239983967
# INFO:root:Batch 2100, training loss : 0.014796613450546628
# INFO:root:Batch 2200, training loss : 0.014124078042098408
# INFO:root:Batch 2300, training loss : 0.01351002397351525
# INFO:root:Epoch 10/10, training loss: 0.013077911851178979 [7.415799140930176s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.02031153909554304
# INFO:root:Dev acc @ top-1: 0.9953632148377125  correct: 1932 out of 1941
# INFO:root:Loading model from temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt

# %%
predict_results = anomaly_detector.predict(test_features)
print (predict_results)
# Out:
# INFO:root:Evaluating test data.
# INFO:root:Finish inference. [47.37079191207886s]
# INFO:root:Calculating acc sum.
# INFO:root:Finish generating store_df.
# INFO:root:Finish counting [2.447575092315674s]
# INFO:root:Best result: f1: 1.0 rc: 1.0 pc: 1.0
# {'f1': 1.0, 'rc': 1.0, 'pc': 1.0, 'pred': 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1803    1
# 1804    1
# 1805    1
# 1806    1
# 1807    1
# Name: window_pred_anomaly_9, Length: 1808, dtype: int64, 'true': 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1803    1
# 1804    1
# 1805    1
# 1806    1
# 1807    1
# Name: window_anomalies, Length: 1808, dtype: int64}
