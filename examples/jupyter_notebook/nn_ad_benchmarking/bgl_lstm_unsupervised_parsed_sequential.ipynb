# %% [markdown]
# ### Log Anomaly Detection on BGL Dataset using LSTM based models
# This is a running example of an end-to-end workflow for Log Anomaly Detection on public dataset BGL using LSTM based neural anomaly detectors.
#
# It is very similar to that on the HDFS dataset. We will only mark out the dataset specific portions of this workflow i.e. the parts that differ between the two datasets.
#
# For a more complete elaboration of the full workflow please refer to `hdfs_lstm_unsupervised_parsed_sequential.ipynb` notebook.

# %%
import os 
from logai.applications.openset.anomaly_detection.openset_anomaly_detection_workflow import OpenSetADWorkflowConfig, validate_config_dict
from logai.utils.file_utils import read_file
from logai.utils.dataset_utils import split_train_dev_test_for_anomaly_detection
import logging 
from logai.dataloader.data_loader import FileDataLoader
from logai.preprocess.bgl_preprocessor import BGLPreprocessor
from logai.information_extraction.log_parser import LogParser
from logai.preprocess.openset_partitioner import OpenSetPartitioner
from logai.analysis.nn_anomaly_detector import NNAnomalyDetector
from logai.information_extraction.log_vectorizer import LogVectorizer
from logai.utils import constants

# %% [markdown]
# ### Loading config from yaml
# While the way to load config from yaml file is generic across all datasets, dive into the yaml file itself to specify particular nuances of your dataset (for e.g. regex patterns or mapping of column names to the LogRecordObject attributes)

# %%
config_path = "configs/bgl_lstm_unsupervised_parsed_sequential_config.yaml"
config_parsed = read_file(config_path)
config_dict = config_parsed["workflow_config"]
validate_config_dict(config_dict)
config = OpenSetADWorkflowConfig.from_dict(config_dict)

# %%
dataloader = FileDataLoader(config.data_loader_config)
logrecord = dataloader.load_data()
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 358455    RAS KERNEL FATAL idoproxy communication failur...
# 358456    RAS KERNEL FATAL idoproxy communication failur...
# 358457    RAS KERNEL FATAL idoproxy communication failur...
# 358458    RAS KERNEL FATAL idoproxy communication failur...
# 358459    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 358460, dtype: object
# /Users/alexander.huang/Workspace/logai/logai/dataloader/data_loader.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[constants.LOG_TIMESTAMPS] = pd.to_datetime(

# %% [markdown]
# ### Preprocessing loaded data using BGLPreprocessor
# This is the only part of the workflow that differs based on the dataset used. Each dataset must have its own Preprocessor class implemented. The main functionalities of the preprocessor class is to help process the raw log data and extract the standard fields of the LogRecordObject (e.g. body, labels, timestamps, span_ids, attributes etc).
#
# For some of the fields (like timestamp) where the extraction is generic, it is already automatically handled in the DataLoader class.
#
# Whereas, for some of the more dataset-specific fields (e.g. span_ids or labels), the custom extraction code has to be implemented in the dataset's corresponding Preprocessor class. For e.g. raw BGL dataset does not have any id associated with the loglines. But most existing log anomaly detection literature does a fixed time-partitioning of the logs and uses these partition indices as ids of the log segments.
#
# If you want to use a different time-partitioning or a different scheme for id-ing the loglines in BGL dataset, you have to write your own custom Preprocessor for BGL to serve that purpose.

# %%
preprocessor = BGLPreprocessor(config.preprocessor_config)
preprocessed_filepath = os.path.join(config.output_dir, 'BGL_11k_processed.csv')            
logrecord = preprocessor.clean_log(logrecord)
logrecord.save_to_csv(preprocessed_filepath)
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 358455    RAS KERNEL FATAL idoproxy communication failur...
# 358456    RAS KERNEL FATAL idoproxy communication failur...
# 358457    RAS KERNEL FATAL idoproxy communication failur...
# 358458    RAS KERNEL FATAL idoproxy communication failur...
# 358459    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 358460, dtype: object

# %%
parser = LogParser(config.log_parser_config)
parsed_result = parser.parse(logrecord.body[constants.LOGLINE_NAME])
logrecord.body[constants.LOGLINE_NAME] = parsed_result[constants.PARSED_LOGLINE_NAME]
parsed_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed.csv')
logrecord.save_to_csv(parsed_filepath)
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 358455    RAS KERNEL FATAL idoproxy communication failur...
# 358456    RAS KERNEL FATAL idoproxy communication failur...
# 358457    RAS KERNEL FATAL idoproxy communication failur...
# 358458    RAS KERNEL FATAL idoproxy communication failur...
# 358459    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 358460, dtype: object

# %%
partitioner = OpenSetPartitioner(config.open_set_partitioner_config)
partitioned_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10.csv')
logrecord = partitioner.partition(logrecord)
logrecord.save_to_csv(partitioned_filepath)
print (logrecord.body[constants.LOGLINE_NAME])
# Out:
# 0         RAS KERNEL INFO instruction cache parity error...
# 1         RAS KERNEL INFO instruction cache parity error...
# 2         RAS KERNEL INFO instruction cache parity error...
# 3         RAS KERNEL INFO instruction cache parity error...
# 4         RAS KERNEL INFO instruction cache parity error...
#                                 ...
# 346567    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346568    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346569    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346570    RAS KERNEL FATAL Lustre mount FAILED ALPHANUM ...
# 346571    RAS KERNEL FATAL idoproxy communication failur...
# Name: logline, Length: 346572, dtype: object

# %%
train_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10_unsupervised_train.csv')
dev_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10_unsupervised_dev.csv')
test_filepath = os.path.join(config.output_dir, 'BGL_11k_parsed_sliding10_unsupervised_test.csv')

(train_data, dev_data, test_data) = split_train_dev_test_for_anomaly_detection(
                logrecord,training_type=config.training_type,
                test_data_frac_neg_class=config.test_data_frac_neg,
                test_data_frac_pos_class=config.test_data_frac_pos,
                shuffle=config.train_test_shuffle
            )

train_data.save_to_csv(train_filepath)
dev_data.save_to_csv(dev_filepath)
test_data.save_to_csv(test_filepath)
print ('Train/Dev/Test Anomalous', len(train_data.labels[train_data.labels[constants.LABELS]==1]), 
                                   len(dev_data.labels[dev_data.labels[constants.LABELS]==1]), 
                                   len(test_data.labels[test_data.labels[constants.LABELS]==1]))
print ('Train/Dev/Test Normal', len(train_data.labels[train_data.labels[constants.LABELS]==0]), 
                                   len(dev_data.labels[dev_data.labels[constants.LABELS]==0]), 
                                   len(test_data.labels[test_data.labels[constants.LABELS]==0]))
# Out:
# indices_train/dev/test:  9503 1941 336941
# Train/Dev/Test Anomalous 0 0 336941
# Train/Dev/Test Normal 9503 1941 0

# %%
vectorizer = LogVectorizer(config.log_vectorizer_config)
vectorizer.fit(train_data)
train_features = vectorizer.transform(train_data)
dev_features = vectorizer.transform(dev_data)
test_features = vectorizer.transform(test_data)

# %%
anomaly_detector = NNAnomalyDetector(config=config.nn_anomaly_detection_config)
anomaly_detector.fit(train_features, dev_features)
# Out:
# INFO:root:Start training on 2376 batches with cpu.
# INFO:root:Batch 100, training loss : 1.086510915160179
# INFO:root:Batch 200, training loss : 0.5830365583673119
# INFO:root:Batch 300, training loss : 0.39607727030913037
# INFO:root:Batch 400, training loss : 0.30436887553427366
# INFO:root:Batch 500, training loss : 0.24499564726836978
# INFO:root:Batch 600, training loss : 0.205032207845555
# INFO:root:Batch 700, training loss : 0.2037280415514085
# INFO:root:Batch 800, training loss : 0.17889216940820915
# INFO:root:Batch 900, training loss : 0.15944159963349294
# INFO:root:Batch 1000, training loss : 0.14380327356606723
# INFO:root:Batch 1100, training loss : 0.1309589400227097
# INFO:root:Batch 1200, training loss : 0.17312054718941605
# INFO:root:Batch 1300, training loss : 0.2145836355474491
# INFO:root:Batch 1400, training loss : 0.20053650532466624
# INFO:root:Batch 1500, training loss : 0.18776037297133977
# INFO:root:Batch 1600, training loss : 0.17638718325804803
# INFO:root:Batch 1700, training loss : 0.16625884361592505
# INFO:root:Batch 1800, training loss : 0.15720262787369493
# INFO:root:Batch 1900, training loss : 0.1490660322689157
# INFO:root:Batch 2000, training loss : 0.14172033514268698
# INFO:root:Batch 2100, training loss : 0.13505808124895252
# INFO:root:Batch 2200, training loss : 0.1289896075571464
# INFO:root:Batch 2300, training loss : 0.1234398342948913
# INFO:root:Epoch 1/10, training loss: 0.11952965891479456 [8.15838098526001s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.10259118395183933
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 0.0005833770998287946
# INFO:root:Batch 200, training loss : 0.00033823085910626103
# INFO:root:Batch 300, training loss : 0.000238652443428388
# INFO:root:Batch 400, training loss : 0.008310903442534254
# INFO:root:Batch 500, training loss : 0.00665535139565327
# INFO:root:Batch 600, training loss : 0.0055507389025145435
# INFO:root:Batch 700, training loss : 0.034456580340504715
# INFO:root:Batch 800, training loss : 0.03016880018205484
# INFO:root:Batch 900, training loss : 0.02683206261064495
# INFO:root:Batch 1000, training loss : 0.024161416404807824
# INFO:root:Batch 1100, training loss : 0.02197552770224733
# INFO:root:Batch 1200, training loss : 0.04225219400595354
# INFO:root:Batch 1300, training loss : 0.049865605556232574
# INFO:root:Batch 1400, training loss : 0.04634388747600626
# INFO:root:Batch 1500, training loss : 0.04328173214861211
# INFO:root:Batch 1600, training loss : 0.04059670354078207
# INFO:root:Batch 1700, training loss : 0.03822399614553861
# INFO:root:Batch 1800, training loss : 0.03611250744410224
# INFO:root:Batch 1900, training loss : 0.03422156024065196
# INFO:root:Batch 2000, training loss : 0.03251843702668339
# INFO:root:Batch 2100, training loss : 0.030976549721107447
# INFO:root:Batch 2200, training loss : 0.02957408220161927
# INFO:root:Batch 2300, training loss : 0.02829297260923815
# INFO:root:Epoch 2/10, training loss: 0.02739112262660875 [8.562802076339722s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.051044757055649134
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 2.3847257853049087e-05
# INFO:root:Batch 200, training loss : 1.411171037375425e-05
# INFO:root:Batch 300, training loss : 1.012941968421425e-05
# INFO:root:Batch 400, training loss : 0.00943899326557414
# INFO:root:Batch 500, training loss : 0.007551703158641885
# INFO:root:Batch 600, training loss : 0.006293441804888668
# INFO:root:Batch 700, training loss : 0.029547343683606023
# INFO:root:Batch 800, training loss : 0.0258994508077069
# INFO:root:Batch 900, training loss : 0.023036714373589954
# INFO:root:Batch 1000, training loss : 0.020742022922951037
# INFO:root:Batch 1100, training loss : 0.01886255182869966
# INFO:root:Batch 1200, training loss : 0.03044672091537677
# INFO:root:Batch 1300, training loss : 0.0375057632924969
# INFO:root:Batch 1400, training loss : 0.03483175471547773
# INFO:root:Batch 1500, training loss : 0.03251372442139412
# INFO:root:Batch 1600, training loss : 0.030485036218895516
# INFO:root:Batch 1700, training loss : 0.028694697822545683
# INFO:root:Batch 1800, training loss : 0.027103029428088423
# INFO:root:Batch 1900, training loss : 0.02567869615412555
# INFO:root:Batch 2000, training loss : 0.024396621572749154
# INFO:root:Batch 2100, training loss : 0.02323650435642819
# INFO:root:Batch 2200, training loss : 0.022181727880374636
# INFO:root:Batch 2300, training loss : 0.021218566145037625
# INFO:root:Epoch 3/10, training loss: 0.02054072310958378 [8.150777101516724s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.029205145182129726
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 4.4011670513555145e-06
# INFO:root:Batch 200, training loss : 2.6041068090876254e-06
# INFO:root:Batch 300, training loss : 1.8791223232028643e-06
# INFO:root:Batch 400, training loss : 0.010124338706024574
# INFO:root:Batch 500, training loss : 0.008099879137012352
# INFO:root:Batch 600, training loss : 0.006750154587206841
# INFO:root:Batch 700, training loss : 0.02475169594466889
# INFO:root:Batch 800, training loss : 0.021724740522337988
# INFO:root:Batch 900, training loss : 0.019334642216876148
# INFO:root:Batch 1000, training loss : 0.017415991625127986
# INFO:root:Batch 1100, training loss : 0.015843258014235254
# INFO:root:Batch 1200, training loss : 0.02506828181401159
# INFO:root:Batch 1300, training loss : 0.03207301163702676
# INFO:root:Batch 1400, training loss : 0.029783594728800416
# INFO:root:Batch 1500, training loss : 0.027799314678281405
# INFO:root:Batch 1600, training loss : 0.026062976354552153
# INFO:root:Batch 1700, training loss : 0.024530837045472337
# INFO:root:Batch 1800, training loss : 0.023168868615048095
# INFO:root:Batch 1900, training loss : 0.021950214525266565
# INFO:root:Batch 2000, training loss : 0.02085337589645799
# INFO:root:Batch 2100, training loss : 0.019860958694128107
# INFO:root:Batch 2200, training loss : 0.018958723795359407
# INFO:root:Batch 2300, training loss : 0.018134915028804502
# INFO:root:Epoch 4/10, training loss: 0.01755517989755623 [8.051831007003784s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.022321781438463795
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 6.170135990259951e-06
# INFO:root:Batch 200, training loss : 3.3449441792754443e-06
# INFO:root:Batch 300, training loss : 2.3368537659014996e-06
# INFO:root:Batch 400, training loss : 0.009875882456119811
# INFO:root:Batch 500, training loss : 0.007901855615943703
# INFO:root:Batch 600, training loss : 0.006585618179869309
# INFO:root:Batch 700, training loss : 0.021155468110775077
# INFO:root:Batch 800, training loss : 0.01859273894410432
# INFO:root:Batch 900, training loss : 0.016556929655591673
# INFO:root:Batch 1000, training loss : 0.01491909454019796
# INFO:root:Batch 1100, training loss : 0.013575022243217555
# INFO:root:Batch 1200, training loss : 0.021830550741443324
# INFO:root:Batch 1300, training loss : 0.02902767563837404
# INFO:root:Batch 1400, training loss : 0.02695489437868809
# INFO:root:Batch 1500, training loss : 0.025158437462398126
# INFO:root:Batch 1600, training loss : 0.023586512626884593
# INFO:root:Batch 1700, training loss : 0.022199497966226715
# INFO:root:Batch 1800, training loss : 0.020966578892861885
# INFO:root:Batch 1900, training loss : 0.019863421199304815
# INFO:root:Batch 2000, training loss : 0.018870563837599136
# INFO:root:Batch 2100, training loss : 0.017972248538924238
# INFO:root:Batch 2200, training loss : 0.017155584991892528
# INFO:root:Batch 2300, training loss : 0.01640992892846897
# INFO:root:Epoch 5/10, training loss: 0.015885201342143235 [8.01283311843872s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.02007434474523821
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 6.763766922404102e-06
# INFO:root:Batch 200, training loss : 3.648316153146425e-06
# INFO:root:Batch 300, training loss : 2.5486384899409132e-06
# INFO:root:Batch 400, training loss : 0.009846161708240953
# INFO:root:Batch 500, training loss : 0.007878750160924923
# INFO:root:Batch 600, training loss : 0.006566783446996081
# INFO:root:Batch 700, training loss : 0.01948601004628536
# INFO:root:Batch 800, training loss : 0.017129722888370783
# INFO:root:Batch 900, training loss : 0.015258555939673586
# INFO:root:Batch 1000, training loss : 0.013752306428886633
# INFO:root:Batch 1100, training loss : 0.012515645933694934
# INFO:root:Batch 1200, training loss : 0.01999994522866131
# INFO:root:Batch 1300, training loss : 0.027462370921987427
# INFO:root:Batch 1400, training loss : 0.025501079536511817
# INFO:root:Batch 1500, training loss : 0.023801287152349984
# INFO:root:Batch 1600, training loss : 0.022313960024556816
# INFO:root:Batch 1700, training loss : 0.021001605756941093
# INFO:root:Batch 1800, training loss : 0.019835063332001125
# INFO:root:Batch 1900, training loss : 0.018791300855175806
# INFO:root:Batch 2000, training loss : 0.017851909619261957
# INFO:root:Batch 2100, training loss : 0.017001978936091504
# INFO:root:Batch 2200, training loss : 0.016229310452163085
# INFO:root:Batch 2300, training loss : 0.015523826385655824
# INFO:root:Epoch 6/10, training loss: 0.01502737215665053 [7.841167211532593s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.019572646831743853
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 7.26083126210142e-06
# INFO:root:Batch 200, training loss : 3.879562982547214e-06
# INFO:root:Batch 300, training loss : 2.66584817192476e-06
# INFO:root:Batch 400, training loss : 0.009813337271262537
# INFO:root:Batch 500, training loss : 0.007852797691463465
# INFO:root:Batch 600, training loss : 0.006545505669542315
# INFO:root:Batch 700, training loss : 0.01879823012183066
# INFO:root:Batch 800, training loss : 0.01651629252869646
# INFO:root:Batch 900, training loss : 0.014713066642023584
# INFO:root:Batch 1000, training loss : 0.01326170145069164
# INFO:root:Batch 1100, training loss : 0.012070090434222703
# INFO:root:Batch 1200, training loss : 0.01884812686876808
# INFO:root:Batch 1300, training loss : 0.026408648146528255
# INFO:root:Batch 1400, training loss : 0.02452251112812701
# INFO:root:Batch 1500, training loss : 0.02288785189298251
# INFO:root:Batch 1600, training loss : 0.021457518133204335
# INFO:root:Batch 1700, training loss : 0.020195452762588852
# INFO:root:Batch 1800, training loss : 0.019073613367555104
# INFO:root:Batch 1900, training loss : 0.01806985818894696
# INFO:root:Batch 2000, training loss : 0.01716647262735105
# INFO:root:Batch 2100, training loss : 0.016349123729140914
# INFO:root:Batch 2200, training loss : 0.01560607927622261
# INFO:root:Batch 2300, training loss : 0.014927642719725201
# INFO:root:Epoch 7/10, training loss: 0.01445022392053721 [7.62025785446167s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.01944228837963185
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Saving model to temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt
# INFO:root:Batch 100, training loss : 8.50651015184667e-06
# INFO:root:Batch 200, training loss : 4.4821368595648895e-06
# INFO:root:Batch 300, training loss : 3.0699482751591252e-06
# INFO:root:Batch 400, training loss : 0.009772283438549998
# INFO:root:Batch 500, training loss : 0.007820288169000236
# INFO:root:Batch 600, training loss : 0.006518581292232165
# INFO:root:Batch 700, training loss : 0.018401987425294624
# INFO:root:Batch 800, training loss : 0.016152082816262715
# INFO:root:Batch 900, training loss : 0.014383605228731966
# INFO:root:Batch 1000, training loss : 0.012962448574909488
# INFO:root:Batch 1100, training loss : 0.011796405968926858
# INFO:root:Batch 1200, training loss : 0.01794693800084847
# INFO:root:Batch 1300, training loss : 0.02554838169720364
# INFO:root:Batch 1400, training loss : 0.02372362501438564
# INFO:root:Batch 1500, training loss : 0.022142168189464836
# INFO:root:Batch 1600, training loss : 0.020758386985666375
# INFO:root:Batch 1700, training loss : 0.019537403570550085
# INFO:root:Batch 1800, training loss : 0.018452084979335606
# INFO:root:Batch 1900, training loss : 0.017481006874078955
# INFO:root:Batch 2000, training loss : 0.016607034016350688
# INFO:root:Batch 2100, training loss : 0.015816296668882256
# INFO:root:Batch 2200, training loss : 0.015097444534820044
# INFO:root:Batch 2300, training loss : 0.014441098068518957
# INFO:root:Epoch 8/10, training loss: 0.013979223180297942 [7.971819162368774s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.019680379731815016
# INFO:root:Dev acc @ top-1: 0.9958784131890778  correct: 1933 out of 1941
# INFO:root:Batch 100, training loss : 8.679380305238738e-06
# INFO:root:Batch 200, training loss : 4.575128442354526e-06
# INFO:root:Batch 300, training loss : 3.132340027889313e-06
# INFO:root:Batch 400, training loss : 0.009796928252637312
# INFO:root:Batch 500, training loss : 0.00783916622606698
# INFO:root:Batch 600, training loss : 0.0065338747174743025
# INFO:root:Batch 700, training loss : 0.018190069374460854
# INFO:root:Batch 800, training loss : 0.015963501925528218
# INFO:root:Batch 900, training loss : 0.014215464071039881
# INFO:root:Batch 1000, training loss : 0.012810990425658269
# INFO:root:Batch 1100, training loss : 0.0116586483689573
# INFO:root:Batch 1200, training loss : 0.017248728560948827
# INFO:root:Batch 1300, training loss : 0.024759908094974557
# INFO:root:Batch 1400, training loss : 0.022991436895424627
# INFO:root:Batch 1500, training loss : 0.02145876185581469
# INFO:root:Batch 1600, training loss : 0.020117671196155994
# INFO:root:Batch 1700, training loss : 0.018934355908221852
# INFO:root:Batch 1800, training loss : 0.017882520096724835
# INFO:root:Batch 1900, training loss : 0.016941403844332768
# INFO:root:Batch 2000, training loss : 0.01609439921717991
# INFO:root:Batch 2100, training loss : 0.015328059029362595
# INFO:root:Batch 2200, training loss : 0.014631380604378715
# INFO:root:Batch 2300, training loss : 0.013995280268668229
# INFO:root:Epoch 9/10, training loss: 0.01354765410650159 [8.152779817581177s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.0198413157148101
# INFO:root:Dev acc @ top-1: 0.9953632148377125  correct: 1932 out of 1941
# INFO:root:Batch 100, training loss : 8.316981588905037e-06
# INFO:root:Batch 200, training loss : 4.3808160698688426e-06
# INFO:root:Batch 300, training loss : 3.000016896805846e-06
# INFO:root:Batch 400, training loss : 0.009826339716606007
# INFO:root:Batch 500, training loss : 0.007862835586162277
# INFO:root:Batch 600, training loss : 0.006553692564118094
# INFO:root:Batch 700, training loss : 0.017826077664060996
# INFO:root:Batch 800, training loss : 0.015641735987604957
# INFO:root:Batch 900, training loss : 0.013929101169175609
# INFO:root:Batch 1000, training loss : 0.012553351776087922
# INFO:root:Batch 1100, training loss : 0.011424598718542234
# INFO:root:Batch 1200, training loss : 0.016576030735373913
# INFO:root:Batch 1300, training loss : 0.02402470544964474
# INFO:root:Batch 1400, training loss : 0.022308723179945946
# INFO:root:Batch 1500, training loss : 0.020821538546206993
# INFO:root:Batch 1600, training loss : 0.01952025199168541
# INFO:root:Batch 1700, training loss : 0.018372057972989898
# INFO:root:Batch 1800, training loss : 0.01735144106748277
# INFO:root:Batch 1900, training loss : 0.01643825752045008
# INFO:root:Batch 2000, training loss : 0.01561639232812066
# INFO:root:Batch 2100, training loss : 0.014872800011251184
# INFO:root:Batch 2200, training loss : 0.014196806995915297
# INFO:root:Batch 2300, training loss : 0.013579595981912964
# INFO:root:Epoch 10/10, training loss: 0.013145262305392804 [8.274809837341309s]
# INFO:root:Evaluating dev data.
# INFO:root:Dev Loss: 0.02038360994895347
# INFO:root:Dev acc @ top-1: 0.9948480164863472  correct: 1931 out of 1941
# INFO:root:Loading model from temp_output/BGL_11k_parsed_sliding10_unsupervised_AD/model_lstm/model.ckpt

# %%
predict_results = anomaly_detector.predict(test_features)
print (predict_results)
# Out:
# INFO:root:Evaluating test data.
# INFO:root:Finish inference. [46.899296045303345s]
# INFO:root:Calculating acc sum.
# INFO:root:Finish generating store_df.
# INFO:root:Finish counting [2.489457845687866s]
# INFO:root:Best result: f1: 1.0 rc: 1.0 pc: 1.0
# {'f1': 1.0, 'rc': 1.0, 'pc': 1.0, 'pred': 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1803    1
# 1804    1
# 1805    1
# 1806    1
# 1807    1
# Name: window_pred_anomaly_8, Length: 1808, dtype: int64, 'true': 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1803    1
# 1804    1
# 1805    1
# 1806    1
# 1807    1
# Name: window_anomalies, Length: 1808, dtype: int64}
